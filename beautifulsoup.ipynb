# %%
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup

# %%
def get_data(pageno):
    url = ('https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_' +
           str(pageno) + '_books?ie=UTF8&pg=' + str(pageno))
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')

    for d in soup.find_all('div', {"class": "zg-grid-general-faceout"}):
        book_name = d.find('div', {"class": "_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
        author_name = d.find('div', {'class': "a-row a-size-small"})
        stars = d.find('span', {'class': "a-icon-alt"})
        votes = d.find("span", {'class': "a-size-small"})
        price = d.find('span', {'class': "p13n-sc-price"})
        link = d.find('a', {'class': 'a-link-normal aok-block'})

        data.append({
            'BookName': book_name.text if book_name else 'NaN',
            'AuthorName': author_name.text if author_name else 'NaN',
            'Ratings': stars.text if stars else 'NaN',
            'Number of Votes': votes.text if votes else 'NaN',
            'Price': price.text if price else 'NaN',
            'Book URL': 'https://amazon.in' + link.get('href') if link else 'NaN',
        })

    return data

soup = get_data(1)
soup
# Out:
# [{'BookName': 'Writing Practice Workbooks - Pack of 4 Early Writing Books for Kids (Writing Fun Series): Write and Practice Capital Letters, Small Letters, Line Tracing Patterns & Numbers 1–10 | Pre-Writing Skills Workbook Set for Preschool & Kindergarten | Ages 3–6 Years | Hours of Learning time | Perfect for Gifting',
#   'AuthorName': 'Wonder House Books',
#   'Ratings': '4.3 out of 5 stars',
#   'Number of Votes': '13,734',
#   'Price': '₹199.00',
#   'Book URL': 'https://amazon.in/Writing-Fun-Set-Books-Practice/dp/9387779777/ref=zg_bs_g_books_d_sccl_20/000-0000000-0000000?psc=1'},
#  {'BookName': 'The Secret of Secrets: The brilliant new Robert Langdon thriller from the internationally bestselling author of THE DA VINCI CODE (Robert Langdon Book 6)',
#   'AuthorName': 'Dan Brown',
#   'Ratings': '5.0 out of 5 stars',
#   'Number of Votes': '1',
#   'Price': '₹977.00',
# ...

# %%
number_of_pages = 3
all_data =[]
for i in range(1,number_of_pages+1):
    all_data.extend(get_data(i))

# %%
df = pd.DataFrame(all_data)

# %%
df['BookName'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Writing Practice Workbooks - Pack of 4 Early W...
# 1      The Secret of Secrets: The brilliant new Rober...
# 2      Mother Mary Comes to Me: From the Booker Prize...
# 3      Truth without apology: For those tired of swee...
# 4      My First Library: Boxset of 10 Board Books for...
#                              ...
# 848    Courage To Be Disliked, The: How to free yours...
# 849                           Amma Diarylo Konni Pageelu
# 850    Colouring Books Super Set: Pack of 6 Crayon Co...
# 851    Disha 20 Practice Sets for LIC Assistant Admin...
# 852    Activities Book For Kids Aged 3+ Years Old | 2...
# Name: BookName, Length: 853, dtype: object>
